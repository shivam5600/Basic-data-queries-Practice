# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\Kumar Shivam\Desktop\Data science\7. Udemy Courses.csv")

# %%
df.shape
# Out:
# (3682, 11)

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
df.head(5)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
df.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
df.groupby('subject').sum().count()
# Out:
# course_id          4
# is_paid            4
# num_subscribers    4
# num_reviews        4
# num_lectures       4
# dtype: int64

# %%
df.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
c=df[df['price']!='Free']

# %%
c.shape
# Out:
# (3372, 11)

# %%
df['num_subscribers'].sort_values(ascending=False).head(3)
# Out:
# 2230    268923
# 776     161029
# 3385    121584
# Name: num_subscribers, dtype: int64

# %%
df.sort_values('num_subscribers', ascending=False)
# Out:
#       course_id                                       course_title  is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    False
# 776       59014                     Coding for Entrepreneurs Basic    False
# 3385     625204                         The Web Developer Bootcamp     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3316     764164              The Complete Web Developer Course 2.0     True
# ...         ...                                                ...      ...
# 2290    1223240  Learn Pirates of the Caribbean by Ear on the P...     True
# 1267    1258666                Financial Statement Auditing Cycles     True
# 2070    1215926                Kickstarter success in 5 easy steps     True
# 1931    1247992  Introduction to Project Management for Finance...     True
# 3165    1087466  Stop Creditors from Harassing you and Avoid Ba...     True
#
# ...

# %%
df.loc[[2070]]
# Out:
#       course_id                         course_title  is_paid price  \
# 2070    1215926  Kickstarter success in 5 easy steps     True    20
#
#       num_subscribers  num_reviews  num_lectures       level content_duration  \
# 2070                0            0            12  All Levels          31 mins
#
#        published_timestamp           subject
# 2070  2017-05-16T14:55:28Z  Business Finance

# %%
df.sort_values('price', ascending=True).head(50)
# Out:
#       course_id                                       course_title  is_paid  \
# 2003     405818  Javascript for Beginners Learn by Doing Practi...     True
# 3106     851288  Smart Trading Techniques for Safe & Consistent...     True
# 2858    1182624  Play Thousands of Songs On The Guitar | Cheate...     True
# 2503    1141708  Managerial Accounting - The Ultimate Beginner ...     True
# 3510     576694                   Ultimate WordPress Plugin Course     True
# 3572     542254               Web Programming Course : Asp.Net MVC     True
# 2864     646906  Playing Piano:  Play Chords and Popular Pieces...     True
# 2053     452684  jQuery for Beginners - Create Website Animatio...     True
# 2248    1055322  Learn Laravel PHP Framework Building Multi Use...     True
# 2874     791030                     Power up HTML5 with JavaScript     True
# 2880    1271182  Practical Film Financing: Finding & Pitching I...     True
# ...

# %%
df[df['subject']=='']
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
df[(df['subject'] =='Graphic Design') & (df['price'] < '100')]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %%
df.published_timestamp = pd.to_datetime(df.published_timestamp)

# %%
df.
df.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration       published_timestamp              subject
# ...

# %%
df['year'] = df['published_timestamp'].dt.year

# %%
df.head(5)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration       published_timestamp              subject  year
# ...

# %%
df[df['year']==2015].sum()
# Out:
# course_id                                                   532314761
# course_title        1 - Concepts of Statistics For Beginners Step ...
# is_paid                                                           952
# price               2002020020202540200203550Free40252014520Free20...
# num_subscribers                                               3475324
# num_reviews                                                    196810
# num_lectures                                                    41930
# level               Beginner LevelAll LevelsIntermediate LevelBegi...
# content_duration    31 mins1 hour6.5 hours1 hour1 hour1.5 hours3.5...
# subject             Business FinanceBusiness FinanceMusical Instru...
# year                                                          2043210
# dtype: object

# %%
df.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
df.groupby('level)
# Out:
#   File "<ipython-input-131-84fb01755f33>", line 1
#     df.groupby('level)
#                       ^
# SyntaxError: EOL while scanning string literal
