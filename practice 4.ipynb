# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv(r"C:\Users\Kumar Shivam\Desktop\Data science\4. covid_19_data.csv")

# %%
df.shape
# Out:
# (321, 6)

# %%
df.head(50
       )
# Out:
#          Date State                    Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN               Afghanistan       1939      60        252
# 1   4/29/2020   NaN                   Albania        766      30        455
# 2   4/29/2020   NaN                   Algeria       3848     444       1702
# 3   4/29/2020   NaN                   Andorra        743      42        423
# 4   4/29/2020   NaN                    Angola         27       2          7
# 5   4/29/2020   NaN       Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN                 Argentina       4285     214       1192
# 7   4/29/2020   NaN                   Armenia       1932      30        900
# 8   4/29/2020   NaN                   Austria      15402     580      12779
# 9   4/29/2020   NaN                Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                   Bahamas         80      11         23
# ...

# %%
df['Date']=df['Date'].replace([4] ,'dada')

# %%
df['Date'].head(5)
# Out:
# 0    4/29/2020
# 1    4/29/2020
# 2    4/29/2020
# 3    4/29/2020
# 4    4/29/2020
# Name: Date, dtype: object

# %%
c= df.isnull().sum()

# %%
df.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
df.dtypes
# Out:
# Date         object
# State        object
# Region       object
# Confirmed     int64
# Deaths        int64
# Recovered     int64
# dtype: object

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Show the
#                     coinfirmed ,deaths,recovered in each region

# %%
df.groupby('Region').sum().head(10)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779

# %%
df.groupby('Region')['Deaths','Recovered'].sum()
# Out:
# <ipython-input-153-c09ebd80d095>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Region')['Deaths','Recovered'].sum()
#                     Deaths  Recovered
# Region
# Afghanistan             60        252
# Albania                 30        455
# Algeria                444       1702
# Andorra                 42        423
# Angola                   2          7
# ...                    ...        ...
# West Bank and Gaza       2         71
# Western Sahara           0          5
# Yemen                    0          1
# Zambia                   3         54
# Zimbabwe                 4          5
#
# [187 rows x 2 columns]

# %%
d = df['Deaths'][::15]
y = df['Recovered'][::15]
print(d)
print(y)
# Out:
# 0        60
# 15     7501
# 30       61
# 45        0
# 60        6
# 75      784
# 90        0
# 105       1
# 120      51
# 135       0
# 150     103
# 165       8
# 180       4
# 195    1946
# 210       0
# 225       6
# 240     134
# 255      16
# 270       2
# 285       0
# 300       3
# 315     308
# Name: Deaths, dtype: int64
# 0         252
# 15      11283
# 30        934
# 45         13
# 60        178
# 75       1391
# 90          7
# 105         6
# 120       307
# 135        98
# 150      2073
# 165        71
# 180         5
# 195         0
# 210        50
# 225       318
# 240         0
# 255         0
# 270         0
# 285    120720
# 300        24
# 315         0
# Name: Recovered, dtype: int64

# %%
plt.plot(d)

# %% [markdown]
# # Q2
#  REMOVE THE RECORDS WHEN CASES RECOVERED IS LESS THAN 10

# %%
df.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
df= df[~(df['Recovered']<10)]

# %%
df.head(
)
# Out:
#         Date State               Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN          Afghanistan       1939      60        252
# 1  4/29/2020   NaN              Albania        766      30        455
# 2  4/29/2020   NaN              Algeria       3848     444       1702
# 3  4/29/2020   NaN              Andorra        743      42        423
# 5  4/29/2020   NaN  Antigua and Barbuda         24       3         11

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-159-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (213, 6)

# %% [markdown]
# # q3
#  region having max no of confirmed cases

# %%
df['Confirmed'].describe()
# Out:
# count       213.000000
# mean       8902.169014
# std       29860.713458
# min           0.000000
# 25%         147.000000
# 50%         649.000000
# 75%        3016.000000
# max      236899.000000
# Name: Confirmed, dtype: float64

# %%
df[df['Confirmed']== 236899]
# Out:
#           Date State Region  Confirmed  Deaths  Recovered
# 153  4/29/2020   NaN  Spain     236899   24275     132929

# %%
df.head()
# Out:
#         Date State               Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN          Afghanistan       1939      60        252
# 1  4/29/2020   NaN              Albania        766      30        455
# 2  4/29/2020   NaN              Algeria       3848     444       1702
# 3  4/29/2020   NaN              Andorra        743      42        423
# 5  4/29/2020   NaN  Antigua and Barbuda         24       3         11

# %%
df[df['Region']=='India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
df['Deaths'].sort_values(ascending=True)
# Out:
# 29         0
# 271        0
# 267        0
# 31         0
# 260        0
#        ...
# 61      6467
# 15      7501
# 57     24087
# 153    24275
# 80     27682
# Name: Deaths, Length: 213, dtype: int64

# %%
df.sort_values(by=['Deaths'],ascending=True)
# Out:
#           Date               State                    Region  Confirmed  \
# 29   4/29/2020                 NaN                  Cambodia        122
# 271  4/29/2020  Northern Territory                 Australia         28
# 267  4/29/2020             Ningxia            Mainland China         75
# 31   4/29/2020                 NaN  Central African Republic         50
# 260  4/29/2020       New Caledonia                    France         18
# ..         ...                 ...                       ...        ...
# 61   4/29/2020                 NaN                   Germany     161539
# 15   4/29/2020                 NaN                   Belgium      47859
# 57   4/29/2020                 NaN                    France     165093
# 153  4/29/2020                 NaN                     Spain     236899
# 80   4/29/2020                 NaN                     Italy     203591
#
#      Deaths  Recovered
# 29        0        119
# 271       0         25
# 267       0         75
# ...

# %%
 #theend
